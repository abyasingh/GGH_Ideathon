# %% [markdown]
# <a href="https://colab.research.google.com/github/abyasingh/GGH_Ideathon/blob/main/air_pollution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import warnings
import seaborn as sns

# %%
per_day = pd.read_csv('/content/air_pollution_data.csv')

# %%
print(per_day.columns)
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
print(per_day['Date'])
# Out:
# 0        2015-01-01
# 1        2015-01-02
# 2        2015-01-03
# 3        2015-01-04
# 4        2015-01-05
#             ...
# 29526    2020-06-27
# 29527    2020-06-28
# 29528    2020-06-29
# 29529    2020-06-30
# 29530    2020-07-01
# Name: Date, Length: 29531, dtype: object

# %%
def getArray(csvfile):
    city_per_day = np.empty((0,16))
    for row in per_day:
        city_per_day = np.vstack((city_per_day, np.array(row)))
    return city_per_day

def getCities(data):
    cities = data['City'].value_counts().to_frame()
    cities = cities.sort_index().index
    for i in cities:
        print(i)

def exploreData(data):
    getCities(data)

# %%
exploreData(per_day)
# Out:
# Ahmedabad
# Aizawl
# Amaravati
# Amritsar
# Bengaluru
# Bhopal
# Brajrajnagar
# Chandigarh
# Chennai
# Coimbatore
# Delhi
# Ernakulam
# Gurugram
# Guwahati
# Hyderabad
# Jaipur
# Jorapokhar
# Kochi
# Kolkata
# Lucknow
# Mumbai
# Patna
# Shillong
# Talcher
# Thiruvananthapuram
# Visakhapatnam

# %%
def getMissingValues(data):
    missing_val = data.isnull().sum()
    missing_val_percentage = 100 * data.isnull().sum() / len(data)
    missin_values_array = pd.concat([missing_val, missing_val_percentage], axis=1)
    missin_values_array = missin_values_array.rename(columns =
                                                     {0 : 'Missing Values', 1 : '% of Total Values'})
    missin_values_array = missin_values_array[
        missin_values_array.iloc[:,1] != 0].sort_values('% of Total Values', ascending=False).round(1)
    return missin_values_array

# %%
def mergeColumns(data):
    data['Date'] = pd.to_datetime(data['Date'])
    data['BTX'] = data['Benzene'] + data['Toluene'] + data['Xylene']
    data.drop(['Benzene','Toluene','Xylene'], axis=1)
    data['Particulate_Matter'] = data['PM2.5'] + data['PM10']
    return data

# %%
def subsetColumns(data):
    pollutants = ['Particulate_Matter', 'NO2', 'CO','SO2', 'O3', 'BTX']
    columns =  ['Date', 'City', 'AQI', 'AQI_Bucket'] + pollutants
    data = data[columns]
    return data, pollutants

# %%
def handleMissingValues(data):
    missing_values = getMissingValues(data)
    updatedCityData = mergeColumns(data)
    updatedCityData, pollutants = subsetColumns(updatedCityData)
    return updatedCityData, pollutants

# %%
updatedCityData, newColumns = handleMissingValues(per_day)
updatedCityData
# Out:
#             Date           City   AQI    AQI_Bucket  Particulate_Matter  \
# 0     2015-01-01      Ahmedabad   NaN           NaN                 NaN
# 1     2015-01-02      Ahmedabad   NaN           NaN                 NaN
# 2     2015-01-03      Ahmedabad   NaN           NaN                 NaN
# 3     2015-01-04      Ahmedabad   NaN           NaN                 NaN
# 4     2015-01-05      Ahmedabad   NaN           NaN                 NaN
# ...          ...            ...   ...           ...                 ...
# 29526 2020-06-27  Visakhapatnam  41.0          Good               65.96
# 29527 2020-06-28  Visakhapatnam  70.0  Satisfactory               98.47
# 29528 2020-06-29  Visakhapatnam  68.0  Satisfactory               88.64
# 29529 2020-06-30  Visakhapatnam  54.0  Satisfactory               66.61
# 29530 2020-07-01  Visakhapatnam  50.0          Good               81.00
#
#          NO2     CO    SO2      O3    BTX
# 0      18.22   0.92  27.64  133.36   0.02
# 1      15.69   0.97  24.55   34.06  12.95
# 2      19.30  17.40  29.07   30.70  25.45
# 3      18.48   1.70  18.59   36.08  15.57
# 4      21.42  22.10  39.33   39.31  28.68
# ...      ...    ...    ...     ...    ...
# 29526  25.06   0.47   8.55   23.30  15.04
# 29527  26.06   0.52  12.72   30.14   3.33
# 29528  29.53   0.48   8.42   30.96   0.02
# 29529  29.26   0.52   9.84   28.30   0.00
# 29530  26.85   0.59   2.10   17.05    NaN
#
# [29531 rows x 10 columns]
# Warning: total number of rows (29531) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
filtered_df = updatedCityData[updatedCityData['City'] == 'Lucknow']
print(filtered_df)
# Out:
#             Date     City   AQI    AQI_Bucket  Particulate_Matter    NO2  \
# 19846 2015-01-01  Lucknow   NaN           NaN                 NaN  13.46
# 19847 2015-01-02  Lucknow   NaN           NaN                 NaN  10.76
# 19848 2015-01-03  Lucknow   NaN           NaN                 NaN  12.43
# 19849 2015-01-04  Lucknow   NaN           NaN                 NaN  12.46
# 19850 2015-01-05  Lucknow   NaN           NaN                 NaN  12.27
# ...          ...      ...   ...           ...                 ...    ...
# 21850 2020-06-27  Lucknow  74.0  Satisfactory                 NaN  19.22
# 21851 2020-06-28  Lucknow  77.0  Satisfactory                 NaN  17.67
# 21852 2020-06-29  Lucknow  65.0  Satisfactory                 NaN  18.47
# 21853 2020-06-30  Lucknow  69.0  Satisfactory                 NaN  11.94
# 21854 2020-07-01  Lucknow  76.0  Satisfactory                 NaN  14.44
#
#           CO     SO2     O3  BTX
# 19846  12.15  169.57  25.92  NaN
# 19847  14.00  169.46  21.66  NaN
# 19848  12.78  169.77  22.40  NaN
# 19849  11.85  169.56  21.41  NaN
# 19850  13.34  169.48  20.60  NaN
# ...      ...     ...    ...  ...
# 21850   0.80    3.77  56.36  NaN
# 21851   0.81    2.85  56.40  NaN
# 21852   0.80    3.36  43.61  NaN
# 21853   0.72    4.31  41.17  NaN
# 21854   0.73    6.02  36.07  NaN
#
# [2009 rows x 10 columns]

# %%
def visualisePollutants(udata, columns):
    data = udata.copy()
    data.set_index('Date',inplace=True)
    axes = data[columns].plot(marker='.', linestyle='None', figsize=(15, 15), subplots=True)
    for ax in axes:
        ax.set_xlabel('Years')
        ax.set_ylabel('ug/m3')

# %%
visualisePollutants(updatedCityData, newColumns)

# %%
def trend_plot(updatedCityData, value):
    data = updatedCityData.copy()
    data['Year'] = [d.year for d in data.Date]
    data['Month'] = [d.strftime('%b') for d in data.Date]
    years = data['Year'].unique()
    fig, axes = plt.subplots(1, 2, figsize=(12,3), dpi= 80)
    sns.boxplot(x='Year', y=value, data=data, ax=axes[0])
    sns.pointplot(x='Month', y=value, data=data.loc[~data.Year.isin([2015, 2020]), :])

    axes[0].set_title('Year-wise Plot', fontsize=18);
    axes[1].set_title('Month-wise Plot', fontsize=18)
    plt.show()

# %%
value='SO2'
trend_plot(updatedCityData,value)

# %%
def visualiseAQI(udata, columns):
    data = udata.copy()
    data.set_index('Date',inplace=True)

    axes = data[columns].plot(marker='.', alpha=0.5, linestyle='None', figsize=(16, 3), subplots=True)
    for ax in axes:
        ax.set_xlabel('Years')
        ax.set_ylabel('AQI')

# %%
visualiseAQI(updatedCityData, ['AQI'])

# %%
value='AQI'
trend_plot(updatedCityData,value)

# %%
city= ['Lucknow']
filtered_city_day = updatedCityData[updatedCityData['Date'] >= '2016-01-01']
AQI = filtered_city_day[filtered_city_day.City.isin(city)][['Date','City','AQI','AQI_Bucket']]

# %%
AQI_pivot = AQI.pivot(index='Date', columns='City', values='AQI')
AQI_pivot.fillna(method='bfill',inplace=True)

# %%
print(AQI_pivot)
# Out:
# City        Lucknow
# Date
# 2016-01-01    375.0
# 2016-01-02    366.0
# 2016-01-03    315.0
# 2016-01-04    304.0
# 2016-01-05    313.0
# ...             ...
# 2020-06-27     74.0
# 2020-06-28     77.0
# 2020-06-29     65.0
# 2020-06-30     69.0
# 2020-07-01     76.0
#
# [1644 rows x 1 columns]

# %%
def getColorBar(city):
    col = []
    for val in AQI_pivot[city]:
        if val < 50:
            col.append('royalblue')
        elif val > 50 and val < 101:
            col.append('lightskyblue')
        elif val > 100 and val < 201:
            col.append('lightsteelblue')
        elif val > 200 and val < 301:
            col.append('peachpuff')
        elif val > 300 and val < 401:
            col.append('lightcoral')
        else:
            col.append('firebrick')
    return col

de = getColorBar('Lucknow')

colors = {'Good':'royalblue', 'Satisfactory':'lightskyblue', 'Moderate':'lightsteelblue', 'Poor':'peachpuff', 'Very Poor':'lightcoral', 'Severe':'firebrick'}
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]

f, ax1 = plt.subplots(1, 1, figsize=(15,3))
ax1.bar(AQI_pivot.index, AQI_pivot['Lucknow'], color = de, width = 0.75)

ax1.legend(handles, labels, loc='upper right')

ax1.title.set_text('Lucknow')

ax1.set_ylabel('AQI')
ax1.set_xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
print(updatedCityData)
# Out:
#             Date           City   AQI    AQI_Bucket  Particulate_Matter  \
# 0     2015-01-01      Ahmedabad   NaN           NaN                 NaN
# 1     2015-01-02      Ahmedabad   NaN           NaN                 NaN
# 2     2015-01-03      Ahmedabad   NaN           NaN                 NaN
# 3     2015-01-04      Ahmedabad   NaN           NaN                 NaN
# 4     2015-01-05      Ahmedabad   NaN           NaN                 NaN
# ...          ...            ...   ...           ...                 ...
# 29526 2020-06-27  Visakhapatnam  41.0          Good               65.96
# 29527 2020-06-28  Visakhapatnam  70.0  Satisfactory               98.47
# 29528 2020-06-29  Visakhapatnam  68.0  Satisfactory               88.64
# 29529 2020-06-30  Visakhapatnam  54.0  Satisfactory               66.61
# 29530 2020-07-01  Visakhapatnam  50.0          Good               81.00
#
#          NO2     CO    SO2      O3    BTX
# 0      18.22   0.92  27.64  133.36   0.02
# 1      15.69   0.97  24.55   34.06  12.95
# 2      19.30  17.40  29.07   30.70  25.45
# 3      18.48   1.70  18.59   36.08  15.57
# 4      21.42  22.10  39.33   39.31  28.68
# ...      ...    ...    ...     ...    ...
# 29526  25.06   0.47   8.55   23.30  15.04
# 29527  26.06   0.52  12.72   30.14   3.33
# 29528  29.53   0.48   8.42   30.96   0.02
# 29529  29.26   0.52   9.84   28.30   0.00
# 29530  26.85   0.59   2.10   17.05    NaN
#
# [29531 rows x 10 columns]

# %%
def aq(val):
    if pd.isna(val) or np.isnan(val):
        return 'N/A'
    if val < 50:
        return 'good'
    elif val < 101:
        return 'satisfactory'
    elif val < 201:
        return 'moderate'
    elif val < 301:
        return 'poor'
    elif val < 401:
        return 'very poor'
    else:
        return 'severe'

updatedCityData['Condition'] = updatedCityData['AQI'].apply(aq)

print(updatedCityData)
# Out:
#             Date           City   AQI    AQI_Bucket  Particulate_Matter  \
# 0     2015-01-01      Ahmedabad   NaN           NaN                 NaN
# 1     2015-01-02      Ahmedabad   NaN           NaN                 NaN
# 2     2015-01-03      Ahmedabad   NaN           NaN                 NaN
# 3     2015-01-04      Ahmedabad   NaN           NaN                 NaN
# 4     2015-01-05      Ahmedabad   NaN           NaN                 NaN
# ...          ...            ...   ...           ...                 ...
# 29526 2020-06-27  Visakhapatnam  41.0          Good               65.96
# 29527 2020-06-28  Visakhapatnam  70.0  Satisfactory               98.47
# 29528 2020-06-29  Visakhapatnam  68.0  Satisfactory               88.64
# 29529 2020-06-30  Visakhapatnam  54.0  Satisfactory               66.61
# 29530 2020-07-01  Visakhapatnam  50.0          Good               81.00
#
#          NO2     CO    SO2      O3    BTX     Condition
# 0      18.22   0.92  27.64  133.36   0.02           N/A
# 1      15.69   0.97  24.55   34.06  12.95           N/A
# 2      19.30  17.40  29.07   30.70  25.45           N/A
# 3      18.48   1.70  18.59   36.08  15.57           N/A
# 4      21.42  22.10  39.33   39.31  28.68           N/A
# ...      ...    ...    ...     ...    ...           ...
# 29526  25.06   0.47   8.55   23.30  15.04          good
# 29527  26.06   0.52  12.72   30.14   3.33  satisfactory
# 29528  29.53   0.48   8.42   30.96   0.02  satisfactory
# 29529  29.26   0.52   9.84   28.30   0.00  satisfactory
# 29530  26.85   0.59   2.10   17.05    NaN  satisfactory
#
# [29531 rows x 11 columns]
# <ipython-input-30-3fbbd15775c4>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   updatedCityData['Condition'] = updatedCityData['AQI'].apply(aq)

# %%
print(updatedCityData.columns)
updatedCityData.loc['Date'] = pd.to_datetime(updatedCityData['Date'])
# Out:
# Index(['Date', 'City', 'AQI', 'AQI_Bucket', 'Particulate_Matter', 'NO2', 'CO',
#        'SO2', 'O3', 'BTX', 'Condition'],
#       dtype='object')
# <ipython-input-31-4f2a3f19bff3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   updatedCityData.loc['Date'] = pd.to_datetime(updatedCityData['Date'])

# %%
updatedCityData = updatedCityData[['City','Date','AQI','AQI_Bucket']]
updatedCityData.head()
# Out:
#         City       Date  AQI AQI_Bucket
# 0  Ahmedabad 2015-01-01  NaN        NaN
# 1  Ahmedabad 2015-01-02  NaN        NaN
# 2  Ahmedabad 2015-01-03  NaN        NaN
# 3  Ahmedabad 2015-01-04  NaN        NaN
# 4  Ahmedabad 2015-01-05  NaN        NaN

# %%
updatedCityData['AQI'] = updatedCityData['AQI'].fillna(updatedCityData['AQI'].mean(axis=0))
updatedCityData
# Out:
# <ipython-input-33-31887ce3446f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   updatedCityData['AQI'] = updatedCityData['AQI'].fillna(updatedCityData['AQI'].mean(axis=0))
#                 City       Date         AQI    AQI_Bucket
# 0          Ahmedabad 2015-01-01  166.463581           NaN
# 1          Ahmedabad 2015-01-02  166.463581           NaN
# 2          Ahmedabad 2015-01-03  166.463581           NaN
# 3          Ahmedabad 2015-01-04  166.463581           NaN
# 4          Ahmedabad 2015-01-05  166.463581           NaN
# ...              ...        ...         ...           ...
# 29527  Visakhapatnam 2020-06-28   70.000000  Satisfactory
# 29528  Visakhapatnam 2020-06-29   68.000000  Satisfactory
# 29529  Visakhapatnam 2020-06-30   54.000000  Satisfactory
# 29530  Visakhapatnam 2020-07-01   50.000000          Good
# Date             NaN        NaT  166.463581           NaN
#
# [29532 rows x 4 columns]
# Warning: total number of rows (29532) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
updatedCityData['City'] = updatedCityData['City'].fillna('')
cities=pd.unique(updatedCityData['City'])
column1= cities+'_AQI'
column2=cities+'_AQI_Bucket'
columns=[*column1,*column2]
updatedCityData.columns
# Out:
# <ipython-input-34-6b933d6e2bae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   updatedCityData['City'] = updatedCityData['City'].fillna('')
# Index(['City', 'Date', 'AQI', 'AQI_Bucket'], dtype='object')

# %%
final_data= pd.DataFrame(index=np.arange('2015-01-01','2020-07-02',dtype='datetime64[D]'), columns=column1)
for city,i in zip(cities, final_data.columns):
    n = len(np.array(updatedCityData[updatedCityData['City'] == city]['AQI']))
    final_data[i][-n:] = np.array(updatedCityData[updatedCityData['City']==city]['AQI'])

final_data=final_data.astype('float64')
final_data=final_data.resample(rule='MS').mean()

# %%
final_data.tail()
# Out:
#             Ahmedabad_AQI  Aizawl_AQI  Amaravati_AQI  Amritsar_AQI  \
# 2020-03-01     273.885922   70.164932      52.548387     86.402051
# 2020-04-01     120.733333   39.233333      44.400000     80.259383
# 2020-05-01     128.677419   24.193548      59.096774     77.677419
# 2020-06-01     101.964239   25.715453      47.866667    101.533333
# 2020-07-01     119.000000   20.000000      54.000000     78.000000
#
#             Bengaluru_AQI  Bhopal_AQI  Brajrajnagar_AQI  Chandigarh_AQI  \
# 2020-03-01      90.741935  115.206153        139.132239       55.419355
# 2020-04-01      68.533333  126.074836        141.728478       48.648786
# 2020-05-01      73.161290  104.451613        148.400558       74.129032
# 2020-06-01      55.166667   71.666667        156.637532       66.500000
# 2020-07-01      43.000000   69.000000        166.463581       66.000000
#
#             Chennai_AQI  Coimbatore_AQI  ...   Kochi_AQI  Kolkata_AQI  \
# 2020-03-01    70.290323      103.876524  ...  130.369793   122.838710
# 2020-04-01    63.500000      120.200885  ...   77.033333    70.366667
# 2020-05-01    78.677419       64.933134  ...   89.997650    53.161290
# 2020-06-01   103.066667       38.366667  ...   93.866667    46.466667
# 2020-07-01    92.000000      166.463581  ...  102.000000    45.000000
#
#             Lucknow_AQI  Mumbai_AQI   Patna_AQI  Shillong_AQI  Talcher_AQI  \
# 2020-03-01   134.000000  104.645161  158.419355     67.870968   128.362744
# 2020-04-01   106.733333   74.333333  131.166667    154.368437   133.282119
# 2020-05-01   119.096774   63.935484  138.516129     32.451613   109.737236
# 2020-06-01    96.500000   53.300000   82.366667     41.597572   115.218766
# 2020-07-01    76.000000   53.000000   98.000000     24.000000   101.000000
#
#             Thiruvananthapuram_AQI  Visakhapatnam_AQI        _AQI
# 2020-03-01               74.741935          87.724632         NaN
# 2020-04-01               57.066667          61.797572         NaN
# 2020-05-01               55.967742          64.903226         NaN
# 2020-06-01               45.400000          82.200000         NaN
# 2020-07-01               41.000000          50.000000  166.463581
#
# [5 rows x 27 columns]
# Warning: Total number of columns (27) exceeds max_columns (20) limiting to first (20) columns.

# %%
a = final_data['Lucknow_AQI']
a.tail()
# Out:
# 2020-03-01    134.000000
# 2020-04-01    106.733333
# 2020-05-01    119.096774
# 2020-06-01     96.500000
# 2020-07-01     76.000000
# Freq: MS, Name: Lucknow_AQI, dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
Lucknow_AQI = final_data['Lucknow_AQI']
result = seasonal_decompose(Lucknow_AQI, model='multiplicative')
result.plot();
Lucknow_AQI
# Out:
# 2015-01-01    166.463581
# 2015-02-01    166.463581
# 2015-03-01    201.170053
# 2015-04-01    120.182119
# 2015-05-01    137.000000
#                  ...
# 2020-03-01    134.000000
# 2020-04-01    106.733333
# 2020-05-01    119.096774
# 2020-06-01     96.500000
# 2020-07-01     76.000000
# Freq: MS, Name: Lucknow_AQI, Length: 67, dtype: float64

# %%
print(updatedCityData)
# Out:
#                 City       Date         AQI    AQI_Bucket
# 0          Ahmedabad 2015-01-01  166.463581           NaN
# 1          Ahmedabad 2015-01-02  166.463581           NaN
# 2          Ahmedabad 2015-01-03  166.463581           NaN
# 3          Ahmedabad 2015-01-04  166.463581           NaN
# 4          Ahmedabad 2015-01-05  166.463581           NaN
# ...              ...        ...         ...           ...
# 29527  Visakhapatnam 2020-06-28   70.000000  Satisfactory
# 29528  Visakhapatnam 2020-06-29   68.000000  Satisfactory
# 29529  Visakhapatnam 2020-06-30   54.000000  Satisfactory
# 29530  Visakhapatnam 2020-07-01   50.000000          Good
# Date                        NaT  166.463581           NaN
#
# [29532 rows x 4 columns]

# %%
Lucknow_AQI=Lucknow_AQI.reset_index()
Lucknow_AQI.columns=['ds','y']
Lucknow_AQI=Lucknow_AQI.set_index('ds')
print(Lucknow_AQI.columns)
# Out:
# Index(['y'], dtype='object')

# %%
print(Lucknow_AQI)
# Out:
#                      y
# ds
# 2015-01-01  166.463581
# 2015-02-01  166.463581
# 2015-03-01  201.170053
# 2015-04-01  120.182119
# 2015-05-01  137.000000
# ...                ...
# 2020-03-01  134.000000
# 2020-04-01  106.733333
# 2020-05-01  119.096774
# 2020-06-01   96.500000
# 2020-07-01   76.000000
#
# [67 rows x 1 columns]

# %%
train=Lucknow_AQI[:-24]
test=Lucknow_AQI[-24:-12]

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
print(scaled_train)
# Out:
# [[0.27825223]
#  [0.27825223]
#  [0.38654875]
#  [0.13383764]
#  [0.1863154 ]
#  [0.2258399 ]
#  [0.15374932]
#  [0.08807454]
#  [0.16592908]
#  [0.50841657]
#  [1.        ]
#  [0.96972584]
#  [0.8900058 ]
#  [0.76465708]
#  [0.43755431]
#  [0.50344749]
#  [0.33255747]
#  [0.24230683]
#  [0.14422627]
#  [0.10204381]
#  [0.08864828]
#  [0.52341441]
#  [0.96213969]
#  [0.97365145]
#  [0.79035575]
#  [0.68367771]
#  [0.52975577]
#  [0.53735535]
#  [0.54586083]
#  [0.31137827]
#  [0.        ]
#  [0.05979003]
#  [0.08916834]
#  [0.56720003]
#  [0.9543388 ]
#  [0.92734941]
#  [0.93822032]
#  [0.75020814]
#  [0.4967404 ]
#  [0.32309096]
#  [0.55653043]
#  [0.30468087]
#  [0.06280973]]

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
n_input = 24
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)
X,y = generator[0]
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.27825223 0.27825223 0.38654875 0.13383764 0.1863154  0.2258399
#  0.15374932 0.08807454 0.16592908 0.50841657 1.         0.96972584
#  0.8900058  0.76465708 0.43755431 0.50344749 0.33255747 0.24230683
#  0.14422627 0.10204381 0.08864828 0.52341441 0.96213969 0.97365145]
# Predict this y:
#  [[0.79035575]]

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_input, n_features)))
model.add(LSTM(50, activation='relu'))
model.add(Dense(25, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit_generator(generator,epochs=300)
# Out:
# <ipython-input-58-a63b2a8d0a68>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator,epochs=300)
# Epoch 1/300
# 43/43 [==============================] - 2s 41ms/step - loss: 0.0357
# Epoch 2/300
# 43/43 [==============================] - 1s 22ms/step - loss: 0.0308
# Epoch 3/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0161
# Epoch 4/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0182
# Epoch 5/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0141
# Epoch 6/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0138
# Epoch 7/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0132
# Epoch 8/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0123
# Epoch 9/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0122
# Epoch 10/300
# 43/43 [==============================] - 1s 32ms/step - loss: 0.0148
# Epoch 11/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0120
# Epoch 12/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0105
# Epoch 13/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0098
# Epoch 14/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0127
# Epoch 15/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0083
# Epoch 16/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0094
# Epoch 17/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0089
# Epoch 18/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0083
# Epoch 19/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0115
# Epoch 20/300
# 43/43 [==============================] - 1s 32ms/step - loss: 0.0160
# Epoch 21/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0113
# Epoch 22/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0088
# Epoch 23/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0082
# Epoch 24/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0071
# Epoch 25/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0055
# Epoch 26/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0074
# Epoch 27/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0062
# Epoch 28/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0080
# Epoch 29/300
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0074
# Epoch 30/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0070
# Epoch 31/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0061
# Epoch 32/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0086
# Epoch 33/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0095
# Epoch 34/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0065
# Epoch 35/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0041
# Epoch 36/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0055
# Epoch 37/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0047
# Epoch 38/300
# 43/43 [==============================] - 1s 23ms/step - loss: 0.0112
# Epoch 39/300
# 43/43 [==============================] - 1s 33ms/step - loss: 0.0063
# Epoch 40/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0066
# Epoch 41/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0066
# Epoch 42/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0058
# Epoch 43/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0086
# Epoch 44/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0054
# Epoch 45/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0055
# Epoch 46/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0047
# Epoch 47/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0039
# Epoch 48/300
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0046
# Epoch 49/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0042
# Epoch 50/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0031
# Epoch 51/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0044
# Epoch 52/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0037
# Epoch 53/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0052
# Epoch 54/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0084
# Epoch 55/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0065
# Epoch 56/300
# 43/43 [==============================] - 1s 23ms/step - loss: 0.0090
# Epoch 57/300
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0048
# Epoch 58/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0036
# Epoch 59/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0058
# Epoch 60/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0072
# Epoch 61/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0062
# Epoch 62/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0049
# Epoch 63/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0040
# Epoch 64/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0028
# Epoch 65/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0037
# Epoch 66/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0037
# Epoch 67/300
# 43/43 [==============================] - 1s 32ms/step - loss: 0.0038
# Epoch 68/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0035
# Epoch 69/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0030
# Epoch 70/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0027
# Epoch 71/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0056
# Epoch 72/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0058
# Epoch 73/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0042
# Epoch 74/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0028
# Epoch 75/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0053
# Epoch 76/300
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0034
# Epoch 77/300
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0049
# Epoch 78/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0040
# Epoch 79/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0052
# Epoch 80/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0047
# Epoch 81/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0038
# Epoch 82/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0035
# Epoch 83/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0035
# Epoch 84/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0056
# Epoch 85/300
# 43/43 [==============================] - 1s 32ms/step - loss: 0.0038
# Epoch 86/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0035
# Epoch 87/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0031
# Epoch 88/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0026
# Epoch 89/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0031
# Epoch 90/300
# 43/43 [==============================] - 1s 22ms/step - loss: 0.0035
# Epoch 91/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0020
# Epoch 92/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0045
# Epoch 93/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0059
# Epoch 94/300
# 43/43 [==============================] - 1s 32ms/step - loss: 0.0037
# Epoch 95/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0038
# Epoch 96/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0047
# Epoch 97/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0038
# Epoch 98/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0051
# Epoch 99/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0029
# Epoch 100/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0042
# Epoch 101/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0028
# Epoch 102/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0043
# Epoch 103/300
# 43/43 [==============================] - 1s 32ms/step - loss: 0.0022
# Epoch 104/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0031
# Epoch 105/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0026
# Epoch 106/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0028
# Epoch 107/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0039
# Epoch 108/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0027
# Epoch 109/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0022
# Epoch 110/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0025
# Epoch 111/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0059
# Epoch 112/300
# 43/43 [==============================] - 1s 27ms/step - loss: 0.0057
# Epoch 113/300
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0053
# Epoch 114/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0028
# Epoch 115/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0025
# Epoch 116/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0028
# Epoch 117/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0024
# Epoch 118/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0026
# Epoch 119/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0044
# Epoch 120/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0041
# Epoch 121/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0025
# Epoch 122/300
# 43/43 [==============================] - 1s 32ms/step - loss: 0.0022
# Epoch 123/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0021
# Epoch 124/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0026
# Epoch 125/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0024
# Epoch 126/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0031
# Epoch 127/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0025
# Epoch 128/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0024
# Epoch 129/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0027
# Epoch 130/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0034
# Epoch 131/300
# 43/43 [==============================] - 1s 29ms/step - loss: 0.0041
# Epoch 132/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0036
# Epoch 133/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0032
# Epoch 134/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0033
# Epoch 135/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0034
# Epoch 136/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0022
# Epoch 137/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0025
# Epoch 138/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0036
# Epoch 139/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0061
# Epoch 140/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0091
# Epoch 141/300
# 43/43 [==============================] - 1s 27ms/step - loss: 0.0077
# Epoch 142/300
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0031
# Epoch 143/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0023
# Epoch 144/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0028
# Epoch 145/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0030
# Epoch 146/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0027
# Epoch 147/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0029
# Epoch 148/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0027
# Epoch 149/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0024
# Epoch 150/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0018
# Epoch 151/300
# 43/43 [==============================] - 1s 23ms/step - loss: 0.0026
# Epoch 152/300
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0029
# Epoch 153/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0020
# Epoch 154/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0039
# Epoch 155/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0023
# Epoch 156/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0024
# Epoch 157/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0022
# Epoch 158/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0018
# Epoch 159/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0019
# Epoch 160/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0050
# Epoch 161/300
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0019
# Epoch 162/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0018
# Epoch 163/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0019
# Epoch 164/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0029
# Epoch 165/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0022
# Epoch 166/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0019
# Epoch 167/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0027
# Epoch 168/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0036
# Epoch 169/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0019
# Epoch 170/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0028
# Epoch 171/300
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0034
# Epoch 172/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0022
# Epoch 173/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0027
# Epoch 174/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0094
# Epoch 175/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0063
# Epoch 176/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0028
# Epoch 177/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0048
# Epoch 178/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0043
# Epoch 179/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0040
# Epoch 180/300
# 43/43 [==============================] - 1s 26ms/step - loss: 0.0022
# Epoch 181/300
# 43/43 [==============================] - 1s 32ms/step - loss: 0.0015
# Epoch 182/300
# 43/43 [==============================] - 1s 24ms/step - loss: 0.0013
# Epoch 183/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0018
# Epoch 184/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0014
# Epoch 185/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0014
# Epoch 186/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0014
# Epoch 187/300
# 43/43 [==============================] - 1s 30ms/step - loss: 0.0023
# Epoch 188/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0051
# Epoch 189/300
# 43/43 [==============================] - 1s 25ms/step - loss: 0.0030
# Epoch 190/300
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0024
# Epoch 191/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0019
# Epoch 192/300
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0013
# Epoch 193/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0013
# Epoch 194/300
# 43/43 [==============================] - 1s 22ms/step - loss: 0.0015
# Epoch 195/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0019
# Epoch 196/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0053
# Epoch 197/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0024
# Epoch 198/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0024
# Epoch 199/300
# 43/43 [==============================] - 1s 32ms/step - loss: 0.0019
# Epoch 200/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0017
# Epoch 201/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0029
# Epoch 202/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0028
# Epoch 203/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0019
# Epoch 204/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0019
# Epoch 205/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0015
# Epoch 206/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0032
# Epoch 207/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0015
# Epoch 208/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0018
# Epoch 209/300
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0013
# Epoch 210/300
# 43/43 [==============================] - 1s 28ms/step - loss: 0.0036
# Epoch 211/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0055
# Epoch 212/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0039
# Epoch 213/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0024
# Epoch 214/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0021
# Epoch 215/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0021
# Epoch 216/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0017
# Epoch 217/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0012
# Epoch 218/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0014
# Epoch 219/300
# 43/43 [==============================] - 1s 33ms/step - loss: 0.0013
# Epoch 220/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0018
# Epoch 221/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0018
# Epoch 222/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0021
# Epoch 223/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0012
# Epoch 224/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0015
# Epoch 225/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0016
# Epoch 226/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0022
# Epoch 227/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0020
# Epoch 228/300
# 43/43 [==============================] - 1s 27ms/step - loss: 0.0038
# Epoch 229/300
# 43/43 [==============================] - 1s 31ms/step - loss: 0.0035
# Epoch 230/300
# 43/43 [==============================] - 1s 22ms/step - loss: 0.0020
# Epoch 231/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0014
# Epoch 232/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0015
# Epoch 233/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0032
# Epoch 234/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0016
# Epoch 235/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0023
# Epoch 236/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0014
# Epoch 237/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0014
# Epoch 238/300
# 43/43 [==============================] - 1s 32ms/step - loss: 0.0022
# Epoch 239/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0018
# Epoch 240/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0014
# Epoch 241/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0012
# Epoch 242/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0011
# Epoch 243/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0011
# Epoch 244/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0027
# Epoch 245/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0033
# Epoch 246/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0037
# Epoch 247/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0024
# Epoch 248/300
# 43/43 [==============================] - 1s 33ms/step - loss: 0.0012
# Epoch 249/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0011
# Epoch 250/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0013
# Epoch 251/300
# 43/43 [==============================] - 1s 20ms/step - loss: 6.4339e-04
# Epoch 252/300
# 43/43 [==============================] - 1s 20ms/step - loss: 6.0316e-04
# Epoch 253/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0010
# Epoch 254/300
# 43/43 [==============================] - 1s 21ms/step - loss: 7.2998e-04
# Epoch 255/300
# 43/43 [==============================] - 1s 20ms/step - loss: 7.0837e-04
# Epoch 256/300
# 43/43 [==============================] - 1s 22ms/step - loss: 0.0014
# Epoch 257/300
# 43/43 [==============================] - 1s 32ms/step - loss: 0.0013
# Epoch 258/300
# 43/43 [==============================] - 1s 20ms/step - loss: 8.6124e-04
# Epoch 259/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0013
# Epoch 260/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0020
# Epoch 261/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0021
# Epoch 262/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0017
# Epoch 263/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0020
# Epoch 264/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0012
# Epoch 265/300
# 43/43 [==============================] - 1s 22ms/step - loss: 0.0033
# Epoch 266/300
# 43/43 [==============================] - 1s 32ms/step - loss: 0.0052
# Epoch 267/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0042
# Epoch 268/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0028
# Epoch 269/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0035
# Epoch 270/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0016
# Epoch 271/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0014
# Epoch 272/300
# 43/43 [==============================] - 1s 21ms/step - loss: 9.2263e-04
# Epoch 273/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0016
# Epoch 274/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0012
# Epoch 275/300
# 43/43 [==============================] - 1s 34ms/step - loss: 9.9913e-04
# Epoch 276/300
# 43/43 [==============================] - 1s 20ms/step - loss: 8.1952e-04
# Epoch 277/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0014
# Epoch 278/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0013
# Epoch 279/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0014
# Epoch 280/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0012
# Epoch 281/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0020
# Epoch 282/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0021
# Epoch 283/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0024
# Epoch 284/300
# 43/43 [==============================] - 1s 28ms/step - loss: 0.0014
# Epoch 285/300
# 43/43 [==============================] - 1s 33ms/step - loss: 0.0012
# Epoch 286/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0011
# Epoch 287/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0022
# Epoch 288/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0013
# Epoch 289/300
# 43/43 [==============================] - 1s 20ms/step - loss: 8.7249e-04
# Epoch 290/300
# 43/43 [==============================] - 1s 20ms/step - loss: 4.4422e-04
# Epoch 291/300
# 43/43 [==============================] - 1s 20ms/step - loss: 9.9917e-04
# Epoch 292/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0016
# Epoch 293/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0013
# Epoch 294/300
# 43/43 [==============================] - 1s 21ms/step - loss: 7.3512e-04
# Epoch 295/300
# 43/43 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 296/300
# 43/43 [==============================] - 2s 36ms/step - loss: 0.0011
# Epoch 297/300
# 43/43 [==============================] - 1s 29ms/step - loss: 0.0014
# Epoch 298/300
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0013
# Epoch 299/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0030
# Epoch 300/300
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0017

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step

# %%
anomaly_dates = Lucknow_AQI.index
anomaly_values = Lucknow_AQI['y']
import matplotlib.pyplot as plt

plt.plot(anomaly_dates, anomaly_values, color='blue', label='Original Data')

threshold = 326

for i in range(len(Lucknow_AQI['y'])):
    if Lucknow_AQI.values[i] > threshold:
        plt.scatter(Lucknow_AQI.index[i], Lucknow_AQI.values[i], color='red', marker='o')

plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Anomaly Detection')
plt.show()

# %%
true_predictions = scaler.inverse_transform(test_predictions)
test['Predictions'] = true_predictions
test.plot(figsize=(12,8))
plt.plot(true_predictions)
# Out:
# <ipython-input-61-a2dd44c3ff05>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %%
scaler.fit(Lucknow_AQI)
scaled_City_AQI=scaler.transform(Lucknow_AQI)
generator = TimeseriesGenerator(scaled_City_AQI, scaled_City_AQI, length=n_input, batch_size=1)
test_predictions = []

first_eval_batch = scaled_City_AQI[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):


    current_pred = model.predict(current_batch)[0]


    test_predictions.append(current_pred)


    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
true_predictions = scaler.inverse_transform(test_predictions)
true_predictions=true_predictions.flatten()
true_preds=pd.DataFrame(true_predictions,columns=['Forecast'])
true_preds=true_preds.set_index(pd.date_range('2020-06-01',periods=12,freq='MS'))

# %%
plt.figure(figsize=(20,8))
plt.grid(True)
plt.plot( true_preds['Forecast'])
plt.plot( Lucknow_AQI['y'])
